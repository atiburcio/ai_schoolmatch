# %% [markdown]
# # College Matching Analysis
#
# This notebook helps you find colleges similar to your target school based on various characteristics like:
# - School type (public/private)
# - Size and enrollment
# - Academic reputation
# - Location and environment
# - Cost and programs
#
# ## Setup Instructions
# 1. Make sure you have set up your OpenAI API key in your environment
# 2. Run each cell in order by clicking the ▶️ button or pressing Shift+Enter
# 3. When you reach the input cell, enter your target school's name
# 4. The analysis will show you similar schools with detailed explanations

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

# %% [markdown]
# ### Ensure we are logging traces to LangGraph

# %%
# Import required libraries
import os
import json
from langchain_app.school_matcher import get_school_recommendations
from db.college_vector_store import CollegeVectorStore

# Initialize the vector store
vector_store = CollegeVectorStore()

# %%
# Check if OpenAI API key is set
if not os.getenv("OPENAI_API_KEY"):
    print("⚠️ Please set your OpenAI API key first!")
    print("You can do this by running the following in a terminal:")
    print('export OPENAI_API_KEY="your-api-key-here"')
else:
    print("✅ OpenAI API key is set")
# Out:
# ✅ OpenAI API key is set

# %% [markdown]
# ## Enter Your Target School
#
# In the cell below, replace "Stanford University" with the name of the school you want to find matches for.  You're allowed to enter 3 rounds of human feedback.
#
# Some example schools you can try:
# - Stanford University
# - MIT
# - University of Michigan
# - Georgia Tech
# - Rice University

# %%
target_school = "Rice University"  # Change this to your target school

# Get recommendations
try:
    recommendations = get_school_recommendations(target_school, vector_store)
    print("\nSchool Recommendations:")
    print("=" * 50)
    print(recommendations)
except Exception as e:
    print(f"❌ An error occurred: {str(e)}")
    print("\nPlease make sure:")
    print("1. Your OpenAI API key is set correctly")
    print("2. The school name is spelled correctly")
    print("3. You have an active internet connection")
# Out:
# Current Recommendations:
# 1. **University of Texas at Austin (Public)**
#     - **Key Similarities with Rice University:**
#         - Strong programs in Business, Engineering, and Computer Science.
#         - Diverse student body.
#         - Emphasis on research and academic excellence.
#     - **Unique Strengths and Opportunities:**
#         - Large research institution providing ample opportunities for hands-on experience.
#         - Vibrant Austin culture offering a mix of art, music, and technology scenes.
#         - Strong tech connections for internships and career placements.
#     - **Academic Program Alignment:**
#         - Both schools offer programs in similar fields like Business and Engineering, ensuring a robust academic match.
#     - **Campus Environment and Culture Fit:**
#         - Diverse student body aligns with Rice's inclusive environment.
#         - Rich athletic tradition might appeal to students interested in sports.
#     - **Cost and Financial Considerations:**
#         - Public institution likely offers more affordable tuition compared to Rice University.
#     - **Religious and Faith-Based Differences to Consider:**
#         - UT Austin is a public university, so it does not have a religious affiliation like Rice University.
#
# 2. **Stanford University (Private)**
#     - **Key Similarities with Rice University:**
#         - Strong programs in Computer Science and Engineering.
#         - Emphasis on academic excellence and research.
#     - **Unique Strengths and Opportunities:**
#         - Silicon Valley location provides proximity to tech industry giants for internships and networking.
#         - Strong entrepreneurship programs for students interested in startups and innovation.
#         - World-class research facilities and extensive funding for research projects.
#     - **Academic Program Alignment:**
#         - Both institutions excel in Computer Science and Engineering, offering alignment in key academic areas.
#     - **Campus Environment and Culture Fit:**
#         - Stanford's culture of innovation and research aligns with Rice's academic rigor.
#         - Strong athletic programs might appeal to students interested in a balanced college experience.
#     - **Cost and Financial Considerations:**
#         - Private institution likely comes with a higher price tag compared to Rice University.
#     - **Religious and Faith-Based Differences to Consider:**
#         - Stanford University is not affiliated with any specific religion, differing from Rice's Presbyterian affiliation.
#
# 🔄 Would you like to refine these recommendations?
# Examples of feedback you can provide:
# - 'I prefer schools in urban areas'
# - 'Looking for schools with strong engineering programs'
# - 'Interested in schools with a smaller student body'
# - 'Want schools with strong research opportunities'
#
# Press Enter to finish, or type your feedback:
#
# 📝 Processing feedback: 'id prefer to see only private schools please'
# Please wait...
#
# Current Recommendations:
# 1. **University of Texas at Austin (Public)**
#    - **Key Similarities with Rice University:**
#      - Strong programs in Business, Engineering, and Computer Science.
#      - Diverse student body and rich athletic tradition.
#    - **Unique Strengths and Opportunities:**
#      - Large research institution with a vibrant Austin culture.
#      - Strong tech connections that offer networking opportunities.
#    - **Academic Program Alignment:**
#      - Both universities offer programs in Business, Engineering, and Computer Science.
#    - **Campus Environment and Culture Fit:**
#      - Vibrant Austin culture aligns with a lively campus atmosphere.
#      - Diverse student body promotes a multicultural experience.
#    - **Cost and Financial Considerations:**
#      - Public university potentially offers more affordable tuition compared to Rice University.
#    - **Religious and Faith-Based Differences to Consider:**
#      - UT Austin is a public university, so it may have a secular approach compared to Rice's non-sectarian stance.
#
# 2. **Stanford University (Private)**
#    - **Key Similarities with Rice University:**
#      - Strong programs in Computer Science and Engineering.
#      - Emphasis on research and academic excellence.
#    - **Unique Strengths and Opportunities:**
#      - Silicon Valley location provides access to tech and entrepreneurship opportunities.
#      - World-class research facilities and extensive research funding.
#    - **Academic Program Alignment:**
#      - Both universities offer programs in Computer Science and Engineering.
#    - **Campus Environment and Culture Fit:**
#      - Strong entrepreneurship programs align with an innovative and forward-thinking campus culture.
#      - Strong athletic programs offer a well-rounded student experience.
#    - **Cost and Financial Considerations:**
#      - Stanford is a private university with potentially higher tuition costs compared to Rice University.
#    - **Religious and Faith-Based Differences to Consider:**
#      - Stanford's religious diversity may differ from Rice's non-sectarian approach, though both prioritize inclusivity.
#
# 🔄 Would you like to refine these recommendations?
# Examples of feedback you can provide:
# - 'I prefer schools in urban areas'
# - 'Looking for schools with strong engineering programs'
# - 'Interested in schools with a smaller student body'
# - 'Want schools with strong research opportunities'
#
# Press Enter to finish, or type your feedback:
#
# School Recommendations:
# ==================================================
# 1. **University of Texas at Austin (Public)**
#    - **Key Similarities with Rice University:**
#      - Strong programs in Business, Engineering, and Computer Science.
#      - Diverse student body and rich athletic tradition.
#    - **Unique Strengths and Opportunities:**
#      - Large research institution with a vibrant Austin culture.
#      - Strong tech connections that offer networking opportunities.
#    - **Academic Program Alignment:**
#      - Both universities offer programs in Business, Engineering, and Computer Science.
#    - **Campus Environment and Culture Fit:**
#      - Vibrant Austin culture aligns with a lively campus atmosphere.
#      - Diverse student body promotes a multicultural experience.
#    - **Cost and Financial Considerations:**
#      - Public university potentially offers more affordable tuition compared to Rice University.
#    - **Religious and Faith-Based Differences to Consider:**
#      - UT Austin is a public university, so it may have a secular approach compared to Rice's non-sectarian stance.
#
# 2. **Stanford University (Private)**
#    - **Key Similarities with Rice University:**
#      - Strong programs in Computer Science and Engineering.
#      - Emphasis on research and academic excellence.
#    - **Unique Strengths and Opportunities:**
#      - Silicon Valley location provides access to tech and entrepreneurship opportunities.
#      - World-class research facilities and extensive research funding.
#    - **Academic Program Alignment:**
#      - Both universities offer programs in Computer Science and Engineering.
#    - **Campus Environment and Culture Fit:**
#      - Strong entrepreneurship programs align with an innovative and forward-thinking campus culture.
#      - Strong athletic programs offer a well-rounded student experience.
#    - **Cost and Financial Considerations:**
#      - Stanford is a private university with potentially higher tuition costs compared to Rice University.
#    - **Religious and Faith-Based Differences to Consider:**
#      - Stanford's religious diversity may differ from Rice's non-sectarian approach, though both prioritize inclusivity.

# %% [markdown]
# ## Understanding the Results
#
# For each recommended school, you'll see:
# 1. **Key Similarities** - How the school compares to your target school
# 2. **Unique Strengths** - What makes this school special
# 3. **Academic Programs** - Available courses and areas of study
# 4. **Campus Culture** - The learning environment and student experience
#
# Use these insights to explore schools that might be a good fit for your interests and goals!
